# %%
# %pip install sentence_transformers

# %%
# Claim
claim = "Artificial intelligence will revolutionize healthcare."

# Sentences
sentences = [
    "AI can assist doctors in diagnosing diseases with greater accuracy.",
    "Machine learning algorithms are used to predict patient outcomes.",
    "AI-driven robots are being developed to perform surgeries.",
    "Artificial intelligence can analyze medical images faster than humans.",
    "AI can help manage and analyze large datasets in healthcare.",
    "Natural language processing can be used to extract information from medical records.",
    "Predictive analytics can forecast disease outbreaks.",
    "AI-powered virtual assistants can provide patients with medical advice.",
    "Artificial intelligence can improve personalized medicine.",
    "AI can be used to develop new drugs and treatments.",
    "AI can optimize hospital workflows and reduce wait times.",
    "Robotic process automation can handle administrative tasks in healthcare.",
    "Deep learning models can identify patterns in patient data.",
    "AI can enhance the accuracy of medical research.",
    "Machine learning can be used to track and manage chronic diseases.",
    "AI can assist in mental health diagnosis and treatment.",
    "AI can help in genetic research and understanding genetic disorders.",
    "AI-based tools can assist in rehabilitation therapy.",
    "AI can improve the efficiency of healthcare systems.",
    "AI can support remote patient monitoring and telemedicine.",
    "AI can help predict patient readmissions.",
    "AI can improve the detection and treatment of rare diseases.",
    "AI can aid in the early detection of cancer.",
    "AI can help in managing and predicting pandemics.",
    "AI can personalize treatment plans based on individual patient data.",
    "AI can help reduce medical errors.",
    "AI can be used in clinical trials to identify suitable participants.",
    "AI can help in the discovery of new biomarkers.",
    "AI can enhance the capabilities of medical imaging technologies.",
    "AI can support the creation of digital health records.",
    "AI can analyze speech patterns to detect cognitive decline.",
    "AI can be used to develop better prosthetics.",
    "AI can help in managing healthcare supply chains.",
    "AI can provide insights from wearable health devices.",
    "AI can improve patient engagement and adherence to treatment plans.",
    "AI can facilitate the development of personalized nutrition plans.",
    "AI can help in understanding and treating neurological disorders.",
    "AI can assist in the analysis of genomic data.",
    "AI can predict disease progression.",
    "AI can support medical decision-making processes.",
    "AI can enhance the quality of life for elderly patients.",
    "AI can help reduce healthcare costs.",
    "AI can support the training and education of healthcare professionals.",
    "AI can help in early intervention for high-risk patients.",
    "AI can provide decision support for complex medical cases.",
    "AI can analyze environmental factors affecting health.",
    "AI can improve patient follow-up and care continuity.",
    "AI can assist in optimizing treatment regimens.",
    "AI can help detect fraudulent activities in healthcare.",
    "AI can enhance public health surveillance systems.",
    "AI can support patient self-management tools.",
    "AI can provide insights into patient behavior and lifestyle.",
    "AI can help integrate various healthcare systems and data sources.",
    "AI can facilitate cross-disciplinary medical research.",
    "AI can provide better support for palliative care.",
    "AI can assist in managing healthcare resources more effectively.",
    "AI can be used to simulate disease spread and impact.",
    "AI can help in the management of mental health crises.",
    "AI can provide better support for rare disease research.",
    "AI can improve the safety and effectiveness of medical devices.",
    "AI can help streamline clinical documentation.",
    "AI can provide better insights into treatment efficacy.",
    "AI can help optimize patient triage processes.",
    "AI can assist in the development of new vaccines.",
    "AI can support the design of healthcare policies.",
    "AI can improve the quality and consistency of healthcare services.",
    "AI can enhance the precision of surgical procedures.",
    "AI can provide real-time analytics in emergency care.",
    "AI can support the identification of adverse drug reactions.",
    "AI can help tailor health interventions to specific populations.",
    "AI can assist in chronic disease prevention.",
    "AI can enhance the management of health insurance claims.",
    "AI can help develop better diagnostic tools.",
    "AI can assist in understanding the impact of social determinants on health.",
    "AI can provide predictive maintenance for medical equipment.",
    "AI can help improve the accuracy of laboratory tests.",
    "AI can support the optimization of healthcare facilities.",
    "AI can provide better insights into patient satisfaction.",
    "AI can help mitigate the impact of healthcare worker shortages.",
    "AI can assist in developing more effective health campaigns.",
    "AI can enhance the transparency and accountability of healthcare systems.",
    "AI can provide better support for home-based healthcare services.",
    "AI can help in the identification of genetic predispositions to diseases.",
    "AI can support the development of regenerative medicine.",
    "AI can improve the management of infectious diseases.",
    "AI can assist in the creation of digital twins for patient care.",
    "AI can help develop better clinical guidelines.",
    "AI can provide better insights into healthcare disparities.",
    "AI can support the integration of complementary and alternative medicine.",
    "AI can enhance the understanding of drug interactions.",
    "AI can help in the design of more effective health interventions.",
    "AI can assist in improving the patient experience.",
    "AI can support the development of health informatics.",
    "AI can provide better support for healthcare decision-makers.",
    "AI can help in the analysis of healthcare utilization patterns.",
    "AI can enhance the management of patient data privacy.",
    "AI can assist in the development of personalized health education."
]

# %%
from reranking.rerank_sentences import rerank_sentences

# %load_ext autoreload
# %autoreload 2

similarities, sorted_indices = rerank_sentences(claim, sentences)

print("Similarities: ", similarities)
print("Sorted indices: ", sorted_indices)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Similarities:  tensor([0.7797, 0.7023, 0.6948, 0.7658, 0.7935, 0.6610, 0.6594, 0.7487, 0.7969,
#         0.7650, 0.7748, 0.7099, 0.6685, 0.7585, 0.6985, 0.7347, 0.6947, 0.6795,
#         0.8492, 0.7601, 0.7548, 0.7627, 0.7406, 0.7462, 0.7034, 0.7796, 0.7049,
#         0.7446, 0.7711, 0.7704, 0.6755, 0.6949, 0.7527, 0.7386, 0.7383, 0.7038,
#         0.7341, 0.6875, 0.7895, 0.8068, 0.7521, 0.7932, 0.7931, 0.7511, 0.8046,
#         0.7400, 0.7634, 0.7486, 0.7599, 0.7348, 0.7534, 0.7701, 0.8034, 0.7538,
#         0.7362, 0.8138, 0.7441, 0.7314, 0.7024, 0.7911, 0.7366, 0.7223, 0.7670,
#         0.7150, 0.8009, 0.8122, 0.7211, 0.7658, 0.7063, 0.7769, 0.7510, 0.7545,
#         0.7033, 0.7436, 0.7410, 0.7034, 0.8054, 0.7378, 0.7587, 0.7537, 0.8130,
#         0.7556, 0.7153, 0.7678, 0.7811, 0.7479, 0.7845, 0.7888, 0.7405, 0.6874,
#         0.7705, 0.7670, 0.8158, 0.8100, 0.7685, 0.7516, 0.7670])
# ...
