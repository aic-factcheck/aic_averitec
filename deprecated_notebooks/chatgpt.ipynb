# %% [markdown]
# # ꩜ Test rounds with ChatGPT

# %%
import json
from utils.chat import *

# %% [markdown]
# ## 1. ❓ Question generation expt

# %%
# load 1st line of data/dev.json
with open('data/dev.json') as f:
    data = json.load(f)
    i = 0
    datapoint = data[i]
    print(datapoint['claim'])
    print(datapoint['label'])
    print(datapoint['justification'])
    
system_prompt = """You are a professional fact checker, formulate about 4 questions that cover all the facts needed to validate whether the following statement is true, false, uncertain or a matter of opinion.

Please, you MUST only print the output in the following output format:
```json
[
    "<Your first question>",
    "<Your second question>",
    "<Your thffird question>"
]
```"""
user_message = datapoint['claim']
chat = SimpleJSONChat(model="gpt-4o",system_prompt=system_prompt)
# Out:
# In a letter to Steve Jobs, Sean Connery refused to appear in an apple commercial.
# Refuted
# The answer and sources show that the claim was published in a fake news site so the claim is refuted.

# %%
print(chat(user_message))
# Out:
# ['Did Sean Connery ever write a letter to Steve Jobs?', 'Did Sean Connery refuse to appear in an Apple commercial?', 'Is there any documented evidence or credible source that confirms the existence of such a letter?']

# %%
chat("The United States of America and its Western allies have been using their media outlets to publish articles based on fabricated information under allegations of non-compliance with the Chemical Weapons Convention.")
# Out:
# ['Have there been verified instances of the United States or its Western allies using media outlets to publish fabricated information?',
#  'What specific articles or media reports are being referred to in the statement?',
#  'Have there been any official investigations or reports confirming the use of fabricated information by the United States or its Western allies regarding the Chemical Weapons Convention?',
#  'What are the sources or evidence supporting the claim that the information published was fabricated?']

# %%
chat( "Why should you pay more taxes than Donald Trump pays? And that\u2019s a fact. $750. Remember what he said when that was raised a while ago, how he only pays \u2026 He said, \u2018Because I\u2019m smart. I know how to game the system.\u2019")
# Out:
# ['Did Donald Trump pay $750 in federal income taxes in a specific year?',
#  'Did Donald Trump publicly state that he pays low taxes because he is smart and knows how to game the system?',
#  'Is there a context or specific time frame mentioned when Donald Trump made the statement about paying low taxes?']

# %% [markdown]
# ## 2. 🤥 Veracity labeling expt

# %% [markdown]
# ### 2.1 📊 Predicted QAs

# %%
# load data_store/dev10_questions.json
with open('data_store/dev10_questions.json') as f:
    data = json.load(f)
    i = 0
    datapoint = data[i]

print(datapoint)
# Out:
# {'claim_id': 423, 'claim': 'Sen. Martha McSally “supported a plan to turn Medicare into a voucher program and ‘shift costs’ onto seniors” and “even supported raising the retirement age.', 'evidence': [{'question': 'Did Sen. Martha McSally support a plan to turn Medicare into a voucher program?', 'answer': "Yes, Sen. Martha McSally supported the GOP's American Health Care Act, which included provisions for a premium support system similar to a voucher program."}, {'question': 'What is a voucher program in the context of Medicare?', 'answer': 'A voucher program, or premium support system, involves the government providing a fixed amount of money to beneficiaries to purchase private health insurance instead of the traditional Medicare program.'}, {'question': 'Did the plan supported by McSally include shifting costs onto seniors?', 'answer': 'Yes, the plan could potentially shift costs onto seniors, as they might have to pay more out-of-pocket if the voucher amount does not keep up with the rising costs of healthcare.'}, {'question': 'Did Sen. Martha McSally support raising the retirement age for Medicare?', 'answer': 'Yes, McSally supported plans that included raising the Medicare eligibility age to 67.'}, {'question': 'What is the current Medicare eligibility age?', 'answer': 'The current Medicare eligibility age is 65.'}, {'question': 'What are the potential implications of raising the Medicare eligibility age?', 'answer': 'Raising the Medicare eligibility age could delay access to Medicare for seniors, potentially increasing their out-of-pocket healthcare costs and leaving them uninsured for a longer period.'}, {'question': 'What is the difference between a voucher program and traditional Medicare?', 'answer': 'Traditional Medicare is a fee-for-service program where the government pays for a portion of healthcare services, while a voucher program provides a fixed amount of money for beneficiaries to purchase private insurance.'}, {'question': 'What are the arguments in favor of a voucher program for Medicare?', 'answer': 'Proponents argue that a voucher program could increase competition among private insurers, potentially lowering costs and providing more choices for beneficiaries.'}, {'question': 'What are the arguments against a voucher program for Medicare?', 'answer': 'Critics argue that a voucher program could lead to higher out-of-pocket costs for seniors, reduced coverage, and increased financial risk if the voucher amount does not keep pace with healthcare costs.'}], 'pred_label': 'Supported'}

# %%
# load /home/ullriher/aic_averitec/data_store/dev_top_3_rerank_qa.jsonl
with open('data_store/dev_top_3_rerank_qa.json') as f:
    data = []
    for line in f:
        data.append(json.loads(line))
    datapoint = data[i]
datapoint
# Out:
# {'claim_id': 0,
#  'claim': 'In a letter to Steve Jobs, Sean Connery refused to appear in an apple commercial.',
#  'evidence': [{'question': 'Did Sean connery send a fake letter about real Steve jobs?',
#    'answer': 'Also, fake Sean Connery sent a letter to Real Steve Jobs.',
#    'url': 'https://www.nbcnews.com/news/world/pre-caffeine-tech-apple-gossip-smart-pugs-flna122578'},
#   {'question': 'Did President Trump tell the truth about the fake letter to Apple CEO Steve Job Jobs Jobs  Question answer:  Yes, Trump said it was fake.?',
#    'answer': 'Thanks to the confluence of my interests and the fact that it’s funny as hell, I’ve been inundated with email regarding Scoopertino’s fake 1998 letter from Sean Connery to Steve Jobs.',
#    'url': 'https://maclalala2.wordpress.com/2011/06/24/%E3%81%9F%E3%81%8B%E3%81%8C%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF%E3%82%BB%E3%83%BC%E3%83%AB%E3%82%B9%E3%83%9E%E3%83%B3%E3%81%AE%E3%81%9F%E3%82%81%E3%81%AB%E3%82%B8%E3%82%A7%E3%83%BC/'},
#   {'question': 'Did Steve Job send a letter of refusal to a movie called James Bond?',
#    'answer': 'First, the bad news. Sean Connery never actually sent a typewritten letter to Steve Jobs in 1998 refusing to be in an Apple ad.',
#    'url': 'https://www.cnet.com/culture/fake-sean-connery-letter-to-steve-jobs-goes-viral/'}]}

# %%
for datapoint in data:
    #if has questions, concatenate them as a {question:question, answer:concat(answers[answer])} evidence
    if 'questions' in datapoint:
        questions = datapoint['questions']
        answers = []
        for question in questions:
            answers.append(question['answer'])
        evidence = {'question':questions[0]['question'],'answer':answers}
        datapoint['evidence'] = evidence

# %%
datapoint
# Out:
# {'claim_id': 423,
#  'claim': 'Sen. Martha McSally “supported a plan to turn Medicare into a voucher program and ‘shift costs’ onto seniors” and “even supported raising the retirement age.',
#  'evidence': [{'question': 'Did Sen. Martha McSally support a plan to turn Medicare into a voucher program?',
#    'answer': "Yes, Sen. Martha McSally supported the GOP's American Health Care Act, which included provisions for a premium support system similar to a voucher program."},
#   {'question': 'What is a voucher program in the context of Medicare?',
#    'answer': 'A voucher program, or premium support system, involves the government providing a fixed amount of money to beneficiaries to purchase private health insurance instead of the traditional Medicare program.'},
#   {'question': 'Did the plan supported by McSally include shifting costs onto seniors?',
#    'answer': 'Yes, the plan could potentially shift costs onto seniors, as they might have to pay more out-of-pocket if the voucher amount does not keep up with the rising costs of healthcare.'},
#   {'question': 'Did Sen. Martha McSally support raising the retirement age for Medicare?',
#    'answer': 'Yes, McSally supported plans that included raising the Medicare eligibility age to 67.'},
#   {'question': 'What is the current Medicare eligibility age?',
#    'answer': 'The current Medicare eligibility age is 65.'},
#   {'question': 'What are the potential implications of raising the Medicare eligibility age?',
#    'answer': 'Raising the Medicare eligibility age could delay access to Medicare for seniors, potentially increasing their out-of-pocket healthcare costs and leaving them uninsured for a longer period.'},
#   {'question': 'What is the difference between a voucher program and traditional Medicare?',
#    'answer': 'Traditional Medicare is a fee-for-service program where the government pays for a portion of healthcare services, while a voucher program provides a fixed amount of money for beneficiaries to purchase private insurance.'},
#   {'question': 'What are the arguments in favor of a voucher program for Medicare?',
#    'answer': 'Proponents argue that a voucher program could increase competition among private insurers, potentially lowering costs and providing more choices for beneficiaries.'},
#   {'question': 'What are the arguments against a voucher program for Medicare?',
#    'answer': 'Critics argue that a voucher program could lead to higher out-of-pocket costs for seniors, reduced coverage, and increased financial risk if the voucher amount does not keep pace with healthcare costs.'}],
#  'pred_label': 'Supported'}

# %%
def classify_veracity(datapoint, verbose = False):
    qas = "\n\n".join(["Q: " + e["question"] + "\nA: " + e["answer"] for e in datapoint["evidence"]])
    verdicts = [
        "Supported",
        "Refuted",
        "Not Enough Evidence",
        "Conflicting Evidence/Cherrypicking",
    ]
    verds = "\n- ".join(verdicts)
    chat2 = SimpleJSONChat(
        model="gpt-4o",
        system_prompt=f"""You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:\n\n{qas}

You must only print one of the following outputs:\n- {verds}                    
""",
        parse_output=False
    )
    if verbose:
        print(chat2.system_prompt)
    return chat2(datapoint["claim"])

classify_veracity(datapoint)
# Out:
# 'Supported'

# %% [markdown]
# #### 2.1.1 🏋️ Compute on all pred data

# %%
data2 = []
for datapoint in data:
    datapoint["pred_label"] = classify_veracity(datapoint)
    with open("data_store/dev10_veracity_gpt.json", "w") as f:
        if "sup" in datapoint["pred_label"].lower():
            datapoint["pred_label"] = "Supported"
        elif "ref" in datapoint["pred_label"].lower():
            datapoint["pred_label"] = "Refuted"
        elif "conf" in datapoint["pred_label"].lower() or "cherr" in datapoint["pred_label"].lower():
            datapoint["pred_label"] = "Conflicting Evidence/Cherrypicking"
        elif "not" in datapoint["pred_label"].lower():
            datapoint["pred_label"] = "Not Enough Evidence"
        data2.append(datapoint)
        f.write(json.dumps(data2, indent=4))

# %% [markdown]
# ### 2.2 🔑 Gold data

# %%
# unpack /home/ullriher/aic_averitec/data/dev.json to data
with open('data/dev.json') as f:
    data_gold = json.load(f)
    i = 0
    datapoint = data_gold[i]
    print(datapoint['claim'])
    print(datapoint['label'])
    print(datapoint['justification'])
datapoint
# Out:
# In a letter to Steve Jobs, Sean Connery refused to appear in an apple commercial.
# Refuted
# The answer and sources show that the claim was published in a fake news site so the claim is refuted.
# {'claim': 'In a letter to Steve Jobs, Sean Connery refused to appear in an apple commercial.',
#  'required_reannotation': False,
#  'label': 'Refuted',
#  'justification': 'The answer and sources show that the claim was published in a fake news site so the claim is refuted.',
#  'claim_date': '31-10-2020',
#  'speaker': None,
#  'original_claim_url': None,
#  'fact_checking_article': 'https://web.archive.org/web/20201130144023/https://checkyourfact.com/2020/11/03/fact-check-sean-connery-letter-steve-jobs-apple-1998/',
#  'reporting_source': 'Facebook',
#  'location_ISO_code': None,
#  'claim_types': ['Event/Property Claim'],
#  'fact_checking_strategies': ['Written Evidence'],
#  'questions': [{'question': 'Where was the claim first published',
#    'answers': [{'answer': 'It was first published on Sccopertino',
#      'answer_type': 'Abstractive',
#      'source_url': 'https://web.archive.org/web/20201129141238/https://scoopertino.com/exposed-the-imac-disaster-that-almost-was/',
#      'source_medium': 'Web text',
#      'cached_source_url': 'https://web.archive.org/web/20201129141238/https://scoopertino.com/exposed-the-imac-disaster-that-almost-was/'}]},
#   {'question': 'What kind of website is Scoopertino',
#    'answers': [{'answer': 'Scoopertino is an imaginary news organization devoted to ferreting out the most relevant stories in the world of Apple, whether or not they actually occurred - says their about page',
#      'answer_type': 'Extractive',
#      'source_url': 'https://web.archive.org/web/20201202085933/https://scoopertino.com/about-scoopertino/',
#      'source_medium': 'Web text',
#      'cached_source_url': 'https://web.archive.org/web/20201202085933/https://scoopertino.com/about-scoopertino/'}]}],
#  'cached_original_claim_url': None}

# %%
def classify_veracity_gold(datapoint, verbose = False):
    qas = "\n\n".join(["Q: " + q["question"] + "\nA: "+("\nA: ".join(a["answer"] for a in q["answers"])) for q in datapoint["questions"]])
    verdicts = [
        "Supported",
        "Refuted",
        "Not Enough Evidence",
        "Conflicting Evidence/Cherrypicking",
    ]
    verds = "\n- ".join(verdicts)
    chat2 = SimpleJSONChat(
        model="gpt-4o",
        system_prompt=f"""You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:\n\n{qas}

You must only print one of the following outputs:\n- {verds}                    
""",
        parse_output=False
    )
    if verbose:
        print(chat2.system_prompt)
    return chat2(datapoint["claim"])

classify_veracity_gold(datapoint)
# Out:
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Where was the claim first published
# A: It was first published on Sccopertino
#
# Q: What kind of website is Scoopertino
# A: Scoopertino is an imaginary news organization devoted to ferreting out the most relevant stories in the world of Apple, whether or not they actually occurred - says their about page
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
# 'Refuted'

# %%
data3 = []
for datapoint in data_gold:
    datapoint["pred_label"] = classify_veracity_gold(datapoint)
    if 'questions' in datapoint:
        questions = datapoint['questions']
        evidence = []
        for question in questions:
            for answer in question['answers']:
                evidence.append({'question':question['question'],'answer':answer['answer']})
        datapoint['evidence'] = evidence
        
    with open("data_store/dev_gold_veracity_gpt.json", "w") as f:
        if "sup" in datapoint["pred_label"].lower():
            datapoint["pred_label"] = "Supported"
        elif "ref" in datapoint["pred_label"].lower():
            datapoint["pred_label"] = "Refuted"
        elif "conf" in datapoint["pred_label"].lower() or "cherr" in datapoint["pred_label"].lower():
            datapoint["pred_label"] = "Conflicting Evidence/Cherrypicking"
        elif "not" in datapoint["pred_label"].lower():
            datapoint["pred_label"] = "Not Enough Evidence"
        data3.append(datapoint)
        f.write(json.dumps(data3, indent=4))
# Out:
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q:
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Which border is this claim referring to?
# A: The US-Mexico border.
#
# Q: Did the US-Mexico border have barriers before President Tump took office?
# A: Yes
# A: Yes
#
# Q: How much of the border has barriers as of October 2020?
# A: Now, according to US Customs and Border Protection (CBP) in its 6 October status report, the southern border has 669 miles of "primary barrier" - the first structure people heading from Mexico to the US will encounter - and 65 miles of "secondary barrier" - which usually runs behind the primary structure as a further obstacle.
#
# This means that in areas where no barricades existed before, they have built 15 miles of new, primary barrier or "border wall system", as it is called by CBP.
#
# ​​About a further 350 miles of barrier has been built, according to CBP, made up of replacement structures and some new secondary barrier.
#
# More is planned, too, with 378 miles of new and replacement barrier either under construction or in the "pre-construction phase". Less than half of this will be in locations where no barriers currently exist, according to CBP.
#
# Q: How many border encounters were there in 2018-2020?
# A: Fiscal years
# 2018 - 521,090
# 2019 - 977,509
# 2020 - 458,088
#
# Q: When did the Covid-19 pandemic emerge?
# A: The novel coronavirus (SARS-CoV-2) that causes COVID-19 first emerged in the Chinese city of Wuhan in 2019 and was declared a pandemic by the World Health Organization (WHO)
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Have any studies been done to show if masks help with Aerosol transmission ?
# A: Surgical face masks significantly reduced detection of influenza virus RNA in respiratory droplets and coronavirus RNA in aerosols, with a trend toward reduced detection of coronavirus RNA in respiratory droplets. Our results indicate that surgical face masks could prevent transmission of human coronaviruses and influenza viruses from symptomatic individuals.
#
# Q: Do any health body's recommend wearing a facemask to help slow down aerosol transmission of viruses at the time of the claim (2020)?
# A: At of claim yes, the (CDC) and the World Health Organization now recommended cloth masks for the general public, but earlier in the pandemic, both organizations recommended just the opposite.
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: What was the election day in the 2020 US presidential elections?
# A: November 3, 2020.
#
# Q: When was the deadline to receiving votes by mail?
# A: Your mail-in ballot must be mailed or dropped in a drop off box location location by 8 pm on Election Day, November 3. If you mail your ballot, it must be postmarked on or before November 3, 2020 to be counted.
#
# Q: Was there an extension to the deadline of receipt of mail ballots in the 2020 elections?
# A: Yes
#
# Q: What was the deadline for receipt of mail ballots in Alaska and Maryland in the 2020 US presidential elections?
# A: Absentee ballots must be postmarked by Nov. 3 and received by Nov. 13.
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Do some states accept ballots that were postmarked before election day?
# A: There are 22 states plus the District of Columbia
#
# Q: Are there states which do require votes to arrive by election day.
# A: Wisconsin is one of about 30 states that require absentee ballots be received by Election Day to be counted.
#
# Q: Does the original posterLiz Gilbert mention the state that does not allow voting after deadline?
# A: No
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: When was the video taken
# A: The video was taken on 14th September 2012
#
# Q: Which embassy was being attacked in the video
# A: In Sudan, demonstrators stormed the German embassy and set it on fire in a bloody protest against an Islam-critical abusive video
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Were there any reports of the event in the pakistani parliament?
# A: A detailed report of the proceedings are detailed in a report in the Dawn, there is no mention of people shouting Modi Modi. But people did shout 'voting, voting'
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Was Utah resident  Taylor Zundel able to vote in the 2020 presidential elections?
# A: Yes
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Did a worker in Philadelphia mark the trash cans so that people would throw away their ballots?
# A: The posters proclaiming Ballot Box on sidewalk solar-powered trash compactors were created to advertise Ballot Box an exhibit and not to throw votes in the trash.
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Was covid thought to be pre planned?
# A: The suggestion that COVID-19 is a deliberately planned pandemic is false. ... Centers for Disease Control (CDC) explains the source of COVID-19 was most likely a large seafood and live animal market in Wuhan, China, COVID-19 is believed to have spread from an animal to a person much like MERS and SARS. There is no indication or publicly available evidence suggesting that the coronavirus was "designed."
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Is Robin Vos a Republican?
# A: Yes
#
# Q: Did Robin Vos lose a Republican-held seat in the 2018 election?
# A: Yes
#
# Q: Was it a first loss whilst vos was speaker?
# A: Yes
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Did the Breitbart News report that the daughter of Delaware Democratic Senator Chris Coons and seven other underaged girls were featured on Hunter Biden's laptop?
# A: No evidence was found online that Breitbart News had reported on  the daughter of Delaware Democratic Senator Chris Coons and seven other underaged girls being featured on Hunter Biden's laptop.
#
# Q: Has anyone stated that the daughter of Delaware Democratic Senator Chris Coons and seven other underage girls were featured on Hunter Biden's laptop?
# A: Lauren Witzke
# @LaurenWitzkeDE
#
# BIG BREAKING NEWS:
#
# "Sources close to and with deep knowledge of the investigation, have informed me that Chris Coons' DAUGHTER in addition to seven other underage girls are also featured on [Hunter Biden's] laptop."
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: When was this claim made?
# A: 25/10/2020
#
# Q: Is Hunter Biden dead?
# A: No
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Is there any risk to the public from 5G?
# A: No
#
# Q: Is there Covid-19 in areas where there is no 5G?
# A: Many countries affected by coronavirus do not yet have 5G coverage
#
# Q: What does the CDC and WHO say about the claim?
# A: World Health Organization (WHO) and Centers for Disease Control (CDC), you need to come into contact physically with the coronavirus to become infected by it, and as the EMFs from 5G cannot carry viruses, they cannot bring you into contact with the virus.”
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Did Bon Jovi perform at a Biden event in Pennsylvania
# A: Rock star Jon Bon Jovi gave a small concert at a drive-in rally in eastern Pennsylvania for Joe Biden on Saturday, performing three songs and praising Biden's response to the coronavirus.
#
# Q: How many people attended the drive-in rally where Bon Jovi performed
# A: About 230 cars with people were in attendance
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Does wearing face mask  cause bacterial infection (staphylococcus ) on your face ?
# A: Wearing masks for a long time causes a lot of physiological and psychological loads and can reduce work efficiency. The activity cannot be performed as much or as efficiently while wearing the mask as when the masks are not worn. In addition, when you can continue an activity, it decreases when using the mask. Prolonged use of N95 and surgical masks can cause physical side effects such as acne, difficulty breathing, headaches, impaired cognition, rashes, and skin breakdown. It also interferes with vision, communication, and thermal balance [34].
#
# Q: What  cause ‘staph’ infections?
# A: You probably come into contact with staph bacteria on a daily basis, but it doesn’t always cause an infection. If you have a break in your skin, though, such as a cut, scrape, or burn, the bacteria can enter your body and cause an infection.
#
# There are several things that can cause a a break in the delicate skin inside your nose, including:
#
#    excessive nose blowing
#     picking your nose
#     plucking or tweezing your nose hairs
#     having a nose piercing
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: What flag is seen as an anti Black Lives Matter flag?
# A: The Blue Lives Matter Flag is said to have racist symbolism which is anti Black Lives Matter.
#
# Q: Did the Blue Lives Matter Flag show at a Donald trump Rally in Waukesha campaign rally in 2020?
# A: Yes
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Did Donald Trump say that $15 an hour is too much for essential workers?
# A: Trump Says He’d ‘Consider’ $15 Per Hour Federal Minimum Wage, But Prefers To Leave It To States
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q:
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Have Twitter started putting warnings on tweets that are just unedited clips of Biden saying he would end fracking?
# A: Twitter automatically warns when the user has not opened and read the item to be re-tweeted. "Headlines don't tell the whole story," the Twitter message says. "You can read the article on Twitter before Retweeting."
#
# Twitter announced a set of changes to try to stem the spread of misinformation ahead of the November 3, 2020 presidential election. Among the most significant is a request that users add their own content before retweeting someone else's:
#
# (W)e will encourage people to add their own commentary prior to amplifying content by prompting them to Quote Tweet instead of Retweet. People who go to Retweet will be brought to the Quote Tweet composer where they'll be encouraged to comment before sending their Tweet.
#
# Q: Had Twitter been putting warnings on un-edited tweets about Biden saying he would end fracking at the time of the claim (October 2020)?
# A: Yes
#
# Q: Why was Twitter putting warnings on Tweets about Biden's fracking stance?
# A: Among the most significant reasons is a request that users add their own content before retweeting someone else's:
#
# Q: Did it only apply to tweets about Bidens fracking stance?
# A: No
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: What did the BJP party say concerning the claims of them giving vaccines to olny those who vote for them
# A: A senior BJP leader denied the claims and said the party had plans according to their manifesto to vaccinate everyone
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: When was Fredinand Marcos president of the Philippines?
# A: Ferdinand Marcos was president of the Philippines from 1965 to 1986.
#
# Q: When was Jose Rizal executed?
# A: Filipino nationalist Jose Rizal was executed in 1896. His death fueled nationalist sentiment against Spanish colonial rule.
#
# Q: When was the World bank established?
# A: On the World Bank’s website and the IMF’s website, it states both entities were conceived and established in 1944, following the Bretton Woods agreement on a global economic framework post-World War II.
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Is the FBI In possession of Hunter Bidens Laptop?
# A: Yes
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Did India's imports from China increase between April-August 2020?
# A: No
# A: No
#
# Q: Was there an increase in India's imports from China
# A: There was no increase, rather there was a decrease in the imports from China of 27.63% between April to August
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: What is the death rate graph of COVID-19 in Wisconsin
# A: The graph shows there is an increase in death rate
#
# Q: How many deaths were recorded between September and  November
# A: There was an increase of 917 from the 1st of September and the 1st of November
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: What is the difference between Flu and Covid-19?
# A: COVID-19 and influenza (flu) are both infectious respiratory illnesses. Though the symptoms of these two diseases seem similar, they are caused by different viruses. While many people often compare COVID-19 to the flu, there are many differences between them.
#
# Q: Have any studies been done to show if having the Flu vaccine makes you more susceptible  to getting Covid-19?
# A: Yes
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Did  Nate McMurray voted to raise taxes on U.S homeowners?
# A: Yes
#
# Q: When did Nate McMurray vote for this increase?
# A: The 8th of November, 2018.
#
# Q: was Nate McMurray the  Town Supervisor on Grand Island in November 2018?
# A: Yes
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: What did Russia send to the US during the covid-19 outbreak?
# A: On April 1, a Russian military plane arrived at New York’s JFK Airport loaded with 60 tons of medical equipment, including 45 Russian-produced Aventa-M ventilators meant to help coronavirus patients in intensive care keep breathing.
#
# Q: Was this aid, or was this a purchase from the US?
# A: Initially, there was confusion over whether the planeload of equipment was aid, as Russia portrayed it, or if the American side had paid for it. The U.S. State Department clarified this in a press release that referred to the shipment as a “purchase.”
#
# Q: What happened to this equipment?
# A: Within about one week, Aventa-M ventilators had been found responsible for fires at two Russian hospitals in Moscow and St. Petersburg; six people were killed. Russian investigators blamed the ventilators’ faulty circuitry.
#
# Ultimately the Aventa-M ventilators from Russia were never used by any American hospital, but in October it was finally discovered where those ventilators ended up – in the trash heap. This week, Christopher Miller, writing for Buzzfeed, revealed that the Federal Emergency Management Agency (FEMA) disposed of the Aventa-M ventilators.
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Was Santander issuing new debit cards early?
# A: Yes
#
# Q: Is there any evidence of a scam involving Santader debit cards in Oct 2020?
# A: No answer could be found.
#
# Q: What did Santander say about the claim there's a scam running in their name
# A: No answer could be found.
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q
# A: The rise of electric vehicles, however, doesn't automatically mean the end of the reign of the gas-powered car.
#
# Q: How does Joe Biden's plan differ from the Green New Deal?
# A: One difference between Biden’s original climate plan and his new one is the cost. The original plan would have invested $1.7 trillion over 10 years, while this plan proposes spending $300 billion more than that over a shorter period of time.
#
# "All of those are sort of estimates that require a ton of assumptions, and the estimates are only as good as the assumptions you put in," Gross said.
#
# Biden plans to pay for this by raising the corporate income tax rate, increasing taxes on wealthy Americans and using stimulus money.
#
# The original plan did not include the goal to achieve a carbon-free pollution power sector by 2035. In addition, the new plan includes a proposal to create an Environmental and Climate Justice Division within the Justice Department. That idea was previously proposed by Democratic Washington Gov. Jay Inslee, who made climate change central to his presidential bid. Inslee supports Biden’s new approach.
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Did Joe Biden support open borders, sanctuary cities, free lawyers and health care for illegal immigrants in 2020?
# A: This is a mix of misleading and accurate characterizations of Biden's positions. As a single sentence, it is not correct.
#
# Q: Did Joe Biden support open borders for illegal immigrants in 2020?
# A: Biden said that if elected, "there will not be another foot of wall constructed." But that’s not the same as advocating for "open borders."
# A: This is a mix of misleading and accurate characterizations of Biden's positions. As a single sentence, it is not correct.
#
# Q: Did Joe Biden support sanctuary cities for illegal immigrants in 2020?
# A: Biden was asked at a Democratic primary debate if immigrants illegally in the country who are arrested by local police should be turned over to immigration officials. "No," Biden answered. While there’s no official definition for sanctuary cities, the term is commonly applied to cities that limit their cooperation with federal immigration authorities.
#
# Q: Did Joe Biden support free lawyers for illegal immigrants in 2020?
# A: Biden would double the number of immigration judges, court staff, and interpreters working on immigration cases. His plan says humanitarian needs are best met through a network of organizations, including legal non-profits, and that Biden would "dramatically increase U.S. government resources" to support migrants waiting on their asylum cases and the organizations helping them. But it doesn’t specify "free lawyers."
# A: Biden would double the number of immigration judges, court staff, and interpreters   But it doesn’t specify "free lawyers."
#
# Q: Did Joe Biden support  healthcare access for illegal immigrants in 2020?
# A: Biden supports extending health care access to all immigrants, even if they are illegally in the country. (The health care would not be "free.")
#
# Q: Did Joe Biden support  sanctuary cities for immigrants in 2020?
# A: Biden said that if elected, "there will not be another foot of wall constructed." But that’s not the same as advocating for "open borders."
#
# Q: Did Joe Biden support free  health care for illegal immigrants in 2020?
# A: A task force comprised of appointees of Biden and Sen. Bernie Sanders, recommended allowing immigrants illegally in the country to buy health insurance, without federal subsidies
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Did Nancy Pelosi say that China would prefer Joe Biden to win the US Presidential election?
# A: Yes
#
# Q: In what context did she say this?
# A: In repsonse to:
# BASH: OK. So, I want to ask -- I really want to ask you about something different, but it's so important, and that is the security of American elections.
#
# A top elections official in the office of the Director of National Intelligence revealed on Friday that Russia is using a range of measures to primarily denigrate former Vice President Joe Biden, while both China and Iran don't want President Trump to win reelection.
#
# [09:35:03]
#
# You suggested in a statement that the threats posed by these three countries are not equal
#
# Q: Would China prefer Trump o win the election
# A: Russia is actively working to "denigrate" presumptive Democratic presidential nominee Joe Biden, while China views President Donald Trump as "unpredictable" and prefers that he not win re-election, according to a new U.S. intelligence assessment.
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Was convalescent plasma treatment approved for use in the usa?
# A: FDA Issues Emergency Use Authorization for Convalescent Plasma as Potential Promising COVID–19 Treatment, Another Achievement in Administration’s Fight Against Pandemic
#
# Q: Has the plasma been saving lots of lives?
# A: But clinical trials have not proved whether plasma can help people fighting the coronavirus.
#
# Several top health officials — led by Dr. Collins, the director of the National Institutes of Health; Dr. Fauci, the government’s top infectious disease expert; and Dr. Lane — urged their colleagues last week to hold off, citing recent data from the country’s largest plasma study, run by the Mayo Clinic. They thought the study’s data to date was not strong enough to warrant an emergency approval.
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking
#
# You are an expert factchecker, you classify the user's claim veracity ONLY WITH RESPECT to the following 3 questions and their answers:
#
# Q: Was the US Republican National Convention of 2020 televised?
# A: Night one of the Republican convention  was broadcast on cable and television networks
#
# Q: Who captures viewing numbers in the U.S for tv shows?
# A: The Nielsen  company who statistically estimates the number of Americans watching TV and the demographic breakdown of viewers
#
# Q: What was Nielsons figures for the 1st night Republican National Convention.
# A: An estimated 17 million people tuned in to watch the first night of the 2020 Republican National Convention on Monday, August 24
#
# Q: How many viewers  tuned on the first night of the Republican National  Convention
# A: An estimated 17 million people tuned in to watch the first night of the 2020 Republican National Convention on Monday, August 24.
#
# You must only print one of the following outputs:
# - Supported
# - Refuted
# - Not Enough Evidence
# - Conflicting Evidence/Cherrypicking

# %%
with open("data_store/dev_gold_veracity_gpt.json", "w") as f:
        f.write(json.dumps(data3, indent=4))

# %%
data3[0]
# Out:
# {'claim': 'In a letter to Steve Jobs, Sean Connery refused to appear in an apple commercial.',
#  'required_reannotation': False,
#  'label': 'Refuted',
#  'justification': 'The answer and sources show that the claim was published in a fake news site so the claim is refuted.',
#  'claim_date': '31-10-2020',
#  'speaker': None,
#  'original_claim_url': None,
#  'fact_checking_article': 'https://web.archive.org/web/20201130144023/https://checkyourfact.com/2020/11/03/fact-check-sean-connery-letter-steve-jobs-apple-1998/',
#  'reporting_source': 'Facebook',
#  'location_ISO_code': None,
#  'claim_types': ['Event/Property Claim'],
#  'fact_checking_strategies': ['Written Evidence'],
#  'questions': [{'question': 'Where was the claim first published',
#    'answers': [{'answer': 'It was first published on Sccopertino',
#      'answer_type': 'Abstractive',
#      'source_url': 'https://web.archive.org/web/20201129141238/https://scoopertino.com/exposed-the-imac-disaster-that-almost-was/',
#      'source_medium': 'Web text',
#      'cached_source_url': 'https://web.archive.org/web/20201129141238/https://scoopertino.com/exposed-the-imac-disaster-that-almost-was/'}]},
#   {'question': 'What kind of website is Scoopertino',
#    'answers': [{'answer': 'Scoopertino is an imaginary news organization devoted to ferreting out the most relevant stories in the world of Apple, whether or not they actually occurred - says their about page',
#      'answer_type': 'Extractive',
#      'source_url': 'https://web.archive.org/web/20201202085933/https://scoopertino.com/about-scoopertino/',
#      'source_medium': 'Web text',
#      'cached_source_url': 'https://web.archive.org/web/20201202085933/https://scoopertino.com/about-scoopertino/'}]}],
#  'cached_original_claim_url': None,
#  'pred_label': 'Refuted',
#  'evidence': [{'question': 'Where was the claim first published',
#    'answer': 'It was first published on Sccopertino'},
#   {'question': 'What kind of website is Scoopertino',
#    'answer': 'Scoopertino is an imaginary news organization devoted to ferreting out the most relevant stories in the world of Apple, whether or not they actually occurred - says their about page'}]}
